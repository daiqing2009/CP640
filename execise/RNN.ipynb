# %%
import numpy as np
import numpy.random as rnd
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.callbacks import EarlyStopping

#A function for our neural net to learn
#Our data is 2 dimensional and if the input
#sequence is (x_i, y_i) the output is
#sum of  x_i*y_i
def f(x):
    return np.sum(a*b for (a,b) in x)

#Generating some data
X_train = np.random.uniform(low=0.0, high=10.0, 
                      size=(1000, 3, 2))
Y_train = np.array([f(x) for x in X_train])

#Building the model
model = Sequential()
model.add(LSTM(200, activation='relu', 
               return_sequences=True, input_shape=(3, 2)))
model.add(LSTM(100, activation='relu', return_sequences=True))
model.add(LSTM(50, activation='relu', return_sequences=True))
model.add(LSTM(25, activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1))
#Training the model
model.compile(optimizer='adam', loss='mse')
early = EarlyStopping(monitor='val_loss',
                              min_delta=0,
                              patience=10,
                              verbose=0, mode='auto')
history = model.fit(X_train, Y_train, epochs=100, 
                    validation_split=0.2, verbose=1,
                    callbacks = [early])

#Model evaluating a simple example
test_input = np.array([[1, 2],
                       [2,3],
                       [4,5]])
test_input = test_input.reshape((1, 3, 2))
test_output = model.predict(test_input, verbose=0)
print(test_output)
#Actual performance metric
X_test = np.random.uniform(low=0.0, high=10.0, 
                      size=(1000, 3, 2))
Y_test = np.array([f(x) for x in X_test])

model.evaluate(X_test, Y_test)
# Out:
# Epoch 1/100
# /var/folders/bj/spr6xdy950jf8sj2svjhs0vh0000gn/T/ipykernel_68841/3856437655.py:13: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return np.sum(a*b for (a,b) in x)
# /Users/qing/.pyenv/versions/venv640/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 6493.4229 - val_loss: 4544.7407
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2453.3608 - val_loss: 637.3586
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 698.5483 - val_loss: 648.2850
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 653.8287 - val_loss: 459.7074
# ...
