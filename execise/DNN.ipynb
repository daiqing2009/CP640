# %%
# !pip install Tensorflow
# !pip install keras
# Out:
# Collecting Tensorflow
#   Downloading tensorflow-2.18.0-cp310-cp310-macosx_12_0_arm64.whl (239.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 MB 17.2 MB/s eta 0:00:0000:0100:01
# Collecting numpy<2.1.0,>=1.26.0
#   Downloading numpy-2.0.2-cp310-cp310-macosx_14_0_arm64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 37.4 MB/s eta 0:00:00a 0:00:01
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.37.1-cp310-cp310-macosx_12_0_arm64.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 27.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from Tensorflow) (2.32.3)
# Requirement already satisfied: keras>=3.5.0 in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from Tensorflow) (3.6.0)
# Collecting flatbuffers>=24.3.25
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Collecting tensorboard<2.19,>=2.18
#   Downloading tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 34.4 MB/s eta 0:00:0000:0100:01
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.16.0-cp310-cp310-macosx_11_0_arm64.whl (38 kB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.5.0-py3-none-any.whl (7.8 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from Tensorflow) (2.1.0)
# Collecting libclang>=13.0.0
#   Downloading libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl (25.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 33.2 MB/s eta 0:00:0000:0100:01
# Collecting ml-dtypes<0.5.0,>=0.4.0
#   Downloading ml_dtypes-0.4.1-cp310-cp310-macosx_10_9_universal2.whl (397 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 398.0/398.0 kB 29.5 MB/s eta 0:00:00
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 10.7 MB/s eta 0:00:00
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.67.1-cp310-cp310-macosx_12_0_universal2.whl (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 27.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: h5py>=3.11.0 in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from Tensorflow) (3.12.1)
# Requirement already satisfied: packaging in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from Tensorflow) (24.1)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from Tensorflow) (5.28.2)
# Requirement already satisfied: setuptools in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from Tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from Tensorflow) (1.16.0)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from Tensorflow) (4.12.2)
# Collecting wheel<1.0,>=0.23.0
#   Downloading wheel-0.44.0-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: namex in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from keras>=3.5.0->Tensorflow) (0.0.8)
# Requirement already satisfied: rich in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from keras>=3.5.0->Tensorflow) (13.9.4)
# Requirement already satisfied: optree in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from keras>=3.5.0->Tensorflow) (0.13.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->Tensorflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->Tensorflow) (2024.8.30)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->Tensorflow) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->Tensorflow) (2.2.3)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.7-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.3/106.3 kB 15.5 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Collecting werkzeug>=1.0.1
#   Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 21.9 MB/s eta 0:00:00
# Collecting MarkupSafe>=2.1.1
#   Downloading MarkupSafe-3.0.2-cp310-cp310-macosx_11_0_arm64.whl (12 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from rich->keras>=3.5.0->Tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from rich->keras>=3.5.0->Tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->Tensorflow) (0.1.2)
# Installing collected packages: libclang, flatbuffers, wrapt, wheel, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, opt-einsum, numpy, MarkupSafe, markdown, grpcio, google-pasta, gast, werkzeug, ml-dtypes, astunparse, tensorboard, Tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.1
#     Uninstalling numpy-2.1.1:
#       Successfully uninstalled numpy-2.1.1
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml_dtypes 0.5.0
#     Uninstalling ml_dtypes-0.5.0:
#       Successfully uninstalled ml_dtypes-0.5.0
# Successfully installed MarkupSafe-3.0.2 Tensorflow-2.18.0 astunparse-1.6.3 flatbuffers-24.3.25 gast-0.6.0 google-pasta-0.2.0 grpcio-1.67.1 libclang-18.1.1 markdown-3.7 ml-dtypes-0.4.1 numpy-2.0.2 opt-einsum-3.4.0 tensorboard-2.18.0 tensorboard-data-server-0.7.2 tensorflow-io-gcs-filesystem-0.37.1 termcolor-2.5.0 werkzeug-3.1.3 wheel-0.44.0 wrapt-1.16.0
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: keras in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (3.6.0)
# Requirement already satisfied: ml-dtypes in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from keras) (0.4.1)
# Requirement already satisfied: optree in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from keras) (0.13.0)
# Requirement already satisfied: numpy in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from keras) (2.0.2)
# Requirement already satisfied: absl-py in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from keras) (2.1.0)
# Requirement already satisfied: rich in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from keras) (13.9.4)
# Requirement already satisfied: h5py in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from keras) (3.12.1)
# Requirement already satisfied: packaging in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from keras) (24.1)
# Requirement already satisfied: namex in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from keras) (0.0.8)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# WARNING: There was an error checking the latest version of pip.

# %%
## Import Sequential from Keras package. ##
# The neural networks are  a linear stack of layers.
# That's why keras calls it "Sequential"
from keras.models import Sequential

## Import Dense from keras layers.##
# A regular fully(densly) connected layer is called a "Dense" in keras
from keras.layers import Dense

## Import clear_session function to reset any previously built models ##
from keras.backend import clear_session

## Import to_categorical function from keras ##
# This function will get a vector of multiple classes (more than two)
# The output will be binary columns 
from keras.utils import to_categorical

# Import train_test_split from sklearn to split the data set.
from sklearn.model_selection import train_test_split

# Import digits data set from sklearn
from sklearn.datasets import load_digits

# Load the data set
digits = load_digits()
# Define X as input data and yy as target/output vector 
X = digits.data
yy= digits.target

# If you print yy, you will see it includes number from 0 to 9.
# using to_categorical function to create binary columns for each class (10 columns in total)
y = to_categorical(yy,10)

# Split data set into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)

# Clear session to make sure that we are not buliding a model on top of a previously built one.
clear_session()

# define the keras model
model = Sequential()

## Add input layer to the model ##
# The layer will be a dense layer. The output of the layer will include 100 units/neurons and the input is 64
# select ReLu function as the activation function 
model.add(Dense(100, input_dim=64, activation='relu'))

## Add first hidden layer ## 
# The input of this layer is defined in last layer (100 units)
# The output is 60 units and the activation is ReLu
model.add(Dense(60, activation='relu'))

## Add output layer ##
# The input of this layer is 60, and the output is  10 (the number of classes)
model.add(Dense(10, activation='sigmoid'))

# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='SGD', metrics=['accuracy'])

# fit the keras model on the dataset
model.fit(X_train, y_train, epochs=20, batch_size=10)
# Out:
# Epoch 1/20
# /Users/qing/MAC/CP-640-Machine Learning/venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - accuracy: 0.2905 - loss: 0.4696
# Epoch 2/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 338us/step - accuracy: 0.7584 - loss: 0.1627
# Epoch 3/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 344us/step - accuracy: 0.8525 - loss: 0.1151
# Epoch 4/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 345us/step - accuracy: 0.8902 - loss: 0.0884
# Epoch 5/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 347us/step - accuracy: 0.9101 - loss: 0.0756
# Epoch 6/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 328us/step - accuracy: 0.9368 - loss: 0.0611
# Epoch 7/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 339us/step - accuracy: 0.9468 - loss: 0.0558
# Epoch 8/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 437us/step - accuracy: 0.9467 - loss: 0.0551
# Epoch 9/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 336us/step - accuracy: 0.9501 - loss: 0.0493
# Epoch 10/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - accuracy: 0.9504 - loss: 0.0490
# Epoch 11/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 337us/step - accuracy: 0.9698 - loss: 0.0415
# Epoch 12/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 347us/step - accuracy: 0.9601 - loss: 0.0384
# Epoch 13/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - accuracy: 0.9690 - loss: 0.0380
# Epoch 14/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - accuracy: 0.9691 - loss: 0.0375
# Epoch 15/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 335us/step - accuracy: 0.9695 - loss: 0.0348
# Epoch 16/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - accuracy: 0.9781 - loss: 0.0299
# Epoch 17/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 348us/step - accuracy: 0.9728 - loss: 0.0331
# Epoch 18/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 333us/step - accuracy: 0.9683 - loss: 0.0326
# Epoch 19/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 337us/step - accuracy: 0.9732 - loss: 0.0315
# Epoch 20/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - accuracy: 0.9779 - loss: 0.0254
